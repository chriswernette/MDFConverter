# %%
import asammdf
import pandas as pd
import numpy as np
from scipy import io
import time

# %%
start_time = time.time()
mdf = asammdf.MDF('W810_TSCDV_004.MF4')
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.04989981651306152 seconds ---

# %%
start_time = time.time()
mdf.export('mat','test.mat', format='7.3')
print("--- %s seconds ---" % (time.time() - start_time))

# %%
start_time = time.time()
df = mdf.to_dataframe()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 4.063482284545898 seconds ---

# %%
start_time = time.time()
io.savemat('test2.mat', {name: col.values for name, col in test.items()}, format='5')
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.21342921257019043 seconds ---

# %%
mdf.get_channel_name(0,1)
# Out:
# 'Comment'

# %%
import pdb; pdb.set_trace()

column_names = list(df.columns)

new_list = []
for item in column_names:
    string = str(item)
    new_string = string.replace(".", "_")
    new_list.append(new_string)
    
df.columns = new_list
# Out:
# --Return--
# > <ipython-input-5-6ea79ea2c256>(1)<module>()->None
# -> import pdb; pdb.set_trace()
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3334)run_code()
# -> sys.excepthook = old_excepthook
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3350)run_code()
# -> outflag = False
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3351)run_code()
# -> return outflag
# (Pdb)  n
# Internal StopIteration: False
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3254)run_ast_nodes()
# -> if (await self.run_code(code, result,  async_=asy)):
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3246)run_ast_nodes()
# -> for node,mode in to_run:
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3247)run_ast_nodes()
# -> if mode == 'exec':
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3248)run_ast_nodes()
# -> mod = Module([node], [])
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3251)run_ast_nodes()
# -> with compiler.extra_flags(getattr(ast, 'PyCF_ALLOW_TOP_LEVEL_AWAIT', 0x0) if self.autoawait else 0x0):
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3252)run_ast_nodes()
# -> code = compiler(mod, cell_name, mode)
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3253)run_ast_nodes()
# -> asy = compare(code)
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3254)run_ast_nodes()
# -> if (await self.run_code(code, result,  async_=asy)):
# (Pdb)  n
# > d:\programdata\anaconda3\envs\mdfconverter\lib\site-packages\ipython\core\interactiveshell.py(3246)run_ast_nodes()
# -> for node,mode in to_run:

# %%
new_list
# Out:
# ['AbsoluteValue',
#  'minTest',
#  'A11',
#  'A11_COUNT',
#  'A2L_bAutonmsBrkEvnt_Fast',
#  'A2L_bBrkPressFault',
#  'A2L_bFricTq_RgnLimReachCheck',
#  'A2L_bPRNDLDir',
#  'A2L_bPrplTqMnRgen_B_Actl',
#  'A2L_bPTRgenMnTqInvalid_CreepSpd',
#  'A2L_bPTRgenMnTqInvalid_Rollback',
#  'A2L_bPTRgenMnTqInvalid_TqMax',
#  'A2L_bPTRgenMnTqInvalid_TqMin',
#  'A2L_bPTSvcBrk_End',
#  'A2L_bPTSvcBrk_Start',
#  'A2L_bPTTqErr_Flg',
#  'A2L_bPTTqRqInvalid_Rollback',
#  'A2L_bPTTqRqInvalid_TqMax',
#  'A2L_bPTTqRqInvalid_TqMin',
#  'A2L_bRgnLimReached',
#  'A2L_bRgnPrefillRq',
#  'A2L_bRgnTqLimSC_ABScheck',
#  'A2L_bRollbackFlg',
#  'A2L_bRollDir',
#  'A2L_bRTRPrefill_Actv',
#  'A2L_bStandstillCheck',
#  'A2L_bTempSoftInd',
#  'A2L_bTempSoftInd2',
#  'A2L_bTot2TqInvalid_Rollback',
#  'A2L_bTot2TqInvalid_TqMax',
#  'A2L_bTot2TqInvalid_TqMin',
#  'A2L_bWhlSpdCheck_Flt',
#  'A2L_FiltDecelErr',
#  'A2L_Fric_Accel_Reference',
#  'A2L_fsMaxPressDeltaFrt',
#  'A2L_fsMaxPressDeltaRr',
#  'A2L_Kd_comp',
#  'A2L_Ki_comp',
#  'A2L_Kp_comp',
#  'A2L_pFricTqFastFltFreq',
#  'A2L_PID_Filt_Diff',
#  'A2L_PID_Filt_Max_In1',
#  'A2L_PID_Filt_Min_In1',
#  'A2L_PID_Filt_Min_In2',
#  'A2L_PT_Accel_Contribution',
#  'A2L_RawDecelErr',
#  'A2L_RawDecelRq',
#  'A2L_RgnPTAccl_MaxValid',
#  'A2L_RgnPTAccl_MinValid',
#  'A2L_RgnPTAccl_Rq_MinValid',
#  'A2L_RL_Accel_Contribution',
#  'A2L_ssFullGradHoldTotTgtTq',
#  'A2L_ssGradHoldTotTgtTq',
#  'A2L_ssMinPTBrkTqAlwd',
#  'A2L_ssPrplWhlRgenMn_Tq_Actl',
#  'A2L_ssPrplWhlTot2_Tq_Actl',
#  'A2L_ssPrplWhlTot_Tq_Rq',
#  'A2L_ssPTLatencyTqMax',
#  'A2L_ssPTLatencyTqMin',
#  'A2L_ssPTRgenMnTqActlPred',
#  'A2L_ssPTTot2_Tq_ActlFltrd',
#  'A2L_ssPTTot2TqActlPred',
#  'A2L_ssPTTotTqRqPred',
#  'A2L_ssPTTqCmd',
#  'A2L_ssPTTqRqMinBrkDstrb',
#  'A2L_ssPTTqRqMinLatAcl',
#  'A2L_ssPTTqRqMinOnAccel',
#  'A2L_ssPTTqRqMinPreABS_RL',
#  'A2L_ssPTTqRqMinRampout',
#  'A2L_ssPTTqRqMinRollback',
#  'A2L_ssPTTqRqMinSlipCtrl',
#  'A2L_ssPTTqRqMinSlipCtrl_NoSlip',
#  'A2L_ssRgnTqLimArb',
#  'A2L_ssRgnTqLimArb_Prefill',
#  'A2L_ssRgnTqLimPreABSRL_S1',
#  'A2L_ssRgnTqLimPreABSRL_S2',
#  'A2L_ssRgnTqLimPreABSRL_S3',
#  'A2L_ssRgnTqLimSC_postABS',
#  'A2L_ssRgnTqLimSC_preABS',
#  'A2L_ssTotTgtTq',
#  'A2L_ssTotTgtTqDecrSpd',
#  'A2L_ssTotTgtTqIncrSpd',
#  'A2L_u_Accel',
#  'A2L_ucAutonmsBrk_EvntType',
#  'A2L_ucAutonmsBrk_EvntTypeIn',
#  'A2L_ucErrCntr_PRNDLDir',
#  'A2L_ucErrCntr_PrplWhlTotTqRq',
#  'A2L_ucErrCntr_PTRgenMnTqActl',
#  'A2L_ucErrCntr_PTTot2TqActl',
#  'A2L_ucErrCntr_RollDir',
#  'A2L_usAdapFactor',
#  'A2L_usAdedCancldPTTq',
#  'A2L_usBrkPressFrt',
#  'A2L_usBrkPressRr',
#  'A2L_usBrkTot_Tq_RqArb',
#  'A2L_usBrkWmupCutoutSpd',
#  'A2L_usFilterFreq_AutonmsEvnt',
#  'A2L_usFricBrkFrtTqRq_CLDC',
#  'A2L_usFricBrkRrTqRq_CLDC',
#  'A2L_usFricBrkTotTqRq_CLDC',
#  'A2L_usFricBrkTotTqRq_SpdWt',
#  'A2L_usFricBrkTotTqUnfilt',
#  'A2L_usFricBrkTq_RgnLimNotReach',
#  'A2L_usFricBrkTq_RgnLimReach',
#  'A2L_usFricTq_Backward',
#  'A2L_usFricTq_Forward',
#  'A2L_usGrabFactor',
#  'A2L_usMaxRgnSpd',
#  'A2L_usPostSlipCtrlCntr',
#  'A2L_usPreABSTqLimMltplr',
#  'A2L_usPTTqAlwdError',
#  'A2L_usRdcdPTDragTq',
#  'A2L_usRgnVehSpd',
#  'A2L_usRollRad',
#  'A2L_usSpdWt_Frt',
#  'A2L_usSpdWt_Rr',
#  'A2L_usTqFrtRatio',
#  'A2L_usVehSpdFront',
#  'A2L_usVehSpdRear',
#  'ABS_COUNT_DOWN',
#  'AccelBound',
#  'ACTUAL_AXLE_TORQ',
#  'ADAPT_KD_REL_ROLL',
#  'ADAPT_PROP_HOLD_ANGLE_THR',
#  'ADAPT_TransRamp',
#  'AdaptRollAccThr',
#  'AdaptRoughMuHold',
#  'AdaptRoughMuRamp',
#  'AdaptSSLin_FRNT',
#  'AdaptSSLin_KD',
#  'AdaptSSLin_KP',
#  'AdaptYaw_KD',
#  'AdaptYaw_KP',
#  'AL_DetectTimerFL',
#  'AL_DetectTimerFR',
#  'AllUnstblCtr',
#  'alpha_opp_axle_left_rps',
#  'alpha_opp_axle_right_rps',
#  'alpha_opp_wh_rps_FL',
#  'alpha_opp_wh_rps_FR',
#  'alpha_opp_wh_rps_RL',
#  'alpha_opp_wh_rps_RR',
#  'ANY_SNSOR_FAIL',
#  'ANY_WHEEL_SPEED_ERROR',
#  'AwdModeSel',
#  'AX_ACC_SNSR_STATUS',
#  'AX_CG_FILTERED',
#  'AX_COMP_UNFLT',
#  'AX_CONF',
#  'Ax_Filtered',
#  'AX_OFFS_VCG_AVG',
#  'AX_OFFS_VCG_DEL',
#  'AX_OFFSET_CTR1',
#  'AX_OFFSET_CTR2',
#  'AX_PLAUS_COUNT',
#  'Ax_Raw',
#  'AX_SNSOR_STATUS',
#  'AX_TRUST_4VREF',
#  'AXLE_RATIO',
#  'AY_ACC_SNSR_STATUS',
#  'Ay_CG_Filtered',
#  'AY_COMP_UNFLT',
#  'AY_DOT_FILT',
#  'Ay_Dyn_Rem_Z1',
#  'Ay_Dyn_Rem_Z2',
#  'Ay_Filtered',
#  'AY_FLT_DR',
#  'AY_FLT_FREQ',
#  'AY_OVER_COSTEER',
#  'Ay_Raw',
#  'AY_SNSOR_STATUS',
#  'AyMuAdj_YC_US_PRECH',
#  'AYSC_TRANSFER_DUMMY_CODE',
#  'AZ4NORMLOAD',
#  'AZ_ACC_SNSR_STATUS',
#  'AZ_COMP_UNFLT',
#  'AZ_FAULT_CLEAR_CNT',
#  'AZ_FAULT_PRESENT',
#  'AZ_FAULT_TIMER',
#  'AZ_PLAUS_PITCH_INT',
#  'AZ_RELIABLE',
#  'AZ_SNSOR_STATUS',
#  'B1',
#  'B1_COUNT',
#  'b_ANY_TRLR_CONNECTED',
#  'b_ECU_IN_CALIBRATION_MODE',
#  'b_ELOCKER_ENGAGED',
#  'b_HDC_ACTIVE_BRAKING',
#  'b_HDC_BUTTON_PRESS',
#  'b_HDC_ENABLEOK',
#  'b_HDC_EXIT',
#  'b_HDC_GRADEGEARMET',
#  'b_HDC_ON',
#  'b_HDC_SETSPDDEC',
#  'b_HDC_SETSPDINC',
#  'b_HILL_DESC_DISABLED',
#  'b_OR_SPD_CONDITION_MET',
#  'b_PAREST_PID_AWLD_ENABLED_VARIANT',
#  'b_REAR_DIFF_CFG',
#  'b_ROLL_RATE_SENSOR_AVAIL',
#  'b_RSC_BRAKE_LAMP_REQ',
#  'b_RSC_CONFIGURED',
#  'b_RSC_DISABLED',
#  'b_THDC_APED_OVERRIDE',
#  'b_THDC_BRK_OVERRIDE',
#  'b_THDC_DEEP_ABS',
#  'b_THDC_DEEP_ABS_RECOVERY',
#  'b_THDC_SFTY_BARR_EXCD',
#  'b_THDC_TRVLDIRAGAINSTGEAR',
#  'b_USE_IMU_SNSOR_SIG',
#  'b_USE_IMU_SNSOR_SIG_NO_RR',
#  'b_YAW_RATE_PLAUS_FAILURE',
#  'b_YSC_DISABLED',
#  'BANK_NO_RR',
#  'BANK_NO_RR_RECENT',
#  'BANK_UNCERT_NO_RR',
#  'BETR_ACTIVE',
#  'BETR_BlwSrf_DB',
#  'BETR_DB',
#  'BETR_EXIT_DB',
#  'BETR_Mu_DB',
#  'BETR_RAMP_OUT_REQ',
#  'BETR_SNSTZD_by_SLIP',
#  'BETR_Spd_DB',
#  'BETR_TIME_NOYRERR',
#  'BETR_TIME_RAMPOUT',
#  'BETR_TQ_SETPNT',
#  'BETR_TQREQ_FDFWD',
#  'BETR_TQREQ_FLT',
#  'BETR_TQREQ_RAW',
#  'BETR_TQREQ_YR_FDBK',
#  'BETR_TRQ_INIT_THIS_LOOP',
#  'BETR_YR_ERR',
#  'BETR_YR_ERR_SSDOT_Lmtd',
#  'BMOD_FY_OS_ETR_REAR',
#  'BMOD_NORMAL_LOAD_OS_ETR',
#  'BMOD_OS_DAMP_CONS_THRESH',
#  'BMOD_OS_PID_CONS_THRESH',
#  'BMod_Uncert',
#  'BMOD_US_ETR_CONS_THRESH',
#  'BMOD_US_FDBK_CONS_THRESH',
#  'BMOD_US_FDFWD_CONS_THRESH',
#  'BMod_Vx',
#  'BPEst_FL',
#  'BPEst_FR',
#  'BPEst_RL',
#  'BPEst_RR',
#  'BPReq_00_YC_REAROS',
#  'BPReq_01_YC_REAROS',
#  'BPReq_DriverBraking',
#  'BPReq_DriverBraking_Z1',
#  'BPReq_FL_CurvCtrl',
#  'BPReq_FL_DeltaRelRollPD',
#  'BPReq_FL_DeltaYawRatePD',
#  'BPReq_FL_final_SlipRegulated',
#  'BPReq_FL_FinalRSC',
#  'BPReq_FL_I',
#  'BPReq_FL_LiftDetect',
#  'BPReq_FL_nonRolAnglCntrl',
#  'BPReq_FL_PD_FLSS_Z1',
#  'BPReq_FL_PD_RelRoll_Z1',
#  'BPReq_FL_PD_YawRate_Z1',
#  'BPReq_FL_PIDDelta',
#  'BPReq_FL_PIDFinal',
#  'BPReq_FL_PIDSumZ1',
#  'BPReq_FL_Pred_FLSS',
#  'BPReq_FL_Pred_PD',
#  'BPReq_FL_Pred_PD_Screened',
#  'BPReq_FL_Pred_RelRoll',
#  'BPReq_FL_Pred_YawRate',
#  'BPReq_FL_SSRA_Final',
#  'BPReq_FL_SSRA_PD_Z1',
#  'BPReq_FL_Trans',
#  'BPReq_FL_TVbB',
#  'BPReq_FL_WHL_MAX_ACTV_AND_DRVR_BRK_PRESS',
#  'BPReq_FL_YC_Final',
#  'BPReq_FL_YC_Integral',
#  'BPReq_FL_YC_PD',
#  'BPReq_FL_YC_PID',
#  'BPReq_FL_YC_PID_Z1',
#  'BPReq_FL_YC_PIDYD',
#  'BPReq_FL_YC_PIDYD_Z1',
#  'BPReq_FL_YC_Prch',
#  'BPReq_FL_YC_RtLmtd',
#  'BPReq_FL_YC_RtLmtd_Z1',
#  'BPReq_FL_YC_US_DISTRB_PD',
#  'BPReq_FL_YC_US_DISTRB_RtLmd',
#  'BPReq_FL_YC_US_DISTRB_RtLmd_Z1',
#  'BPReq_FL_YC_US_PRECH',
#  'BPReq_FL_YC_US_PRECH_tmp',
#  'BPReq_FL_YC_US_PRECH_Z1',
#  'BPReq_FR_CurvCtrl',
#  'BPReq_FR_DeltaRelRollPD',
#  'BPReq_FR_DeltaYawRatePD',
#  'BPReq_FR_final_SlipRegulated',
#  'BPReq_FR_FinalRSC',
#  'BPReq_FR_I',
#  'BPReq_FR_LiftDetect',
#  'BPReq_FR_nonRolAnglCntrl',
#  'BPReq_FR_PD_FLSS_Z1',
#  'BPReq_FR_PD_RelRoll_Z1',
#  'BPReq_FR_PD_YawRate_Z1',
#  'BPReq_FR_PIDDelta',
#  'BPReq_FR_PIDFinal',
#  'BPReq_FR_PIDSumZ1',
#  'BPReq_FR_Pred_FLSS',
#  'BPReq_FR_Pred_PD',
#  'BPReq_FR_Pred_PD_Screened',
#  'BPReq_FR_Pred_RelRoll',
#  'BPReq_FR_Pred_YawRate',
#  'BPReq_FR_SSRA_Final',
#  'BPReq_FR_SSRA_PD_Z1',
#  'BPReq_FR_Trans',
#  'BPReq_FR_TVbB',
#  'BPReq_FR_WHL_MAX_ACTV_AND_DRVR_BRK_PRESS',
#  'BPReq_FR_YC_Final',
#  'BPReq_FR_YC_Integral',
#  'BPReq_FR_YC_PD',
#  'BPReq_FR_YC_PID',
#  'BPReq_FR_YC_PID_Z1',
#  'BPReq_FR_YC_PIDYD',
#  'BPReq_FR_YC_PIDYD_Z1',
#  'BPReq_FR_YC_Prch',
#  'BPReq_FR_YC_RtLmtd',
#  'BPReq_FR_YC_RtLmtd_Z1',
#  'BPReq_FR_YC_US_DISTRB_PD',
#  'BPReq_FR_YC_US_DISTRB_RtLmd',
#  'BPReq_FR_YC_US_DISTRB_RtLmd_Z1',
#  'BPReq_FR_YC_US_PRECH',
#  'BPReq_FR_YC_US_PRECH_tmp',
#  'BPReq_FR_YC_US_PRECH_Z1',
#  'BPReq_PrDynDrvngFL',
#  'BPReq_PrDynDrvngFR',
#  'BPReq_PrechargeFL',
#  'BPReq_PrechargeFR',
#  'BPReq_PrefillFL',
#  'BPReq_PrefillFR',
#  'BPReq_RL_CurvCtrl',
#  'BPReq_RL_final_SlipRegulated',
#  'BPReq_RL_FinalRSC',
#  'BPReq_RL_LiftDetect',
#  'BPReq_RL_TVbB',
#  'BPReq_RL_WHL_MAX_ACTV_AND_DRVR_BRK_PRESS',
#  'BPReq_RL_YC_Final',
#  'BPReq_RL_YC_Integral',
#  'BPReq_RL_YC_PD',
#  'BPReq_RL_YC_PID',
#  'BPReq_RL_YC_PID_Z1',
#  'BPReq_RL_YC_PIDYD',
#  'BPReq_RL_YC_PIDYD_Z1',
#  'BPReq_RL_YC_RtLmtd',
#  'BPReq_RL_YC_RtLmtd_Z1',
#  'BPReq_RL_YC_US_DISTRB_PD',
#  'BPReq_RL_YC_US_DISTRB_RtLmd',
#  'BPReq_RL_YC_US_DISTRB_RtLmd_Z1',
#  'BPReq_RL_YC_US_PRECH',
#  'BPReq_RL_YC_US_PRECH_tmp',
#  'BPReq_RL_YC_US_PRECH_Z1',
#  'BPReq_RR_CurvCtrl',
#  'BPReq_RR_final_SlipRegulated',
#  'BPReq_RR_FinalRSC',
#  'BPReq_RR_LiftDetect',
#  'BPReq_RR_TVbB',
#  'BPReq_RR_WHL_MAX_ACTV_AND_DRVR_BRK_PRESS',
#  'BPReq_RR_YC_Final',
#  'BPReq_RR_YC_Integral',
#  'BPReq_RR_YC_PD',
#  'BPReq_RR_YC_PID',
#  'BPReq_RR_YC_PID_Z1',
#  'BPReq_RR_YC_PIDYD',
#  'BPReq_RR_YC_PIDYD_Z1',
#  'BPReq_RR_YC_RtLmtd',
#  'BPReq_RR_YC_RtLmtd_Z1',
#  'BPReq_RR_YC_US_DISTRB_PD',
#  'BPReq_RR_YC_US_DISTRB_RtLmd',
#  'BPReq_RR_YC_US_DISTRB_RtLmd_Z1',
#  'BPReq_RR_YC_US_PRECH',
#  'BPReq_RR_YC_US_PRECH_tmp',
#  'BPReq_RR_YC_US_PRECH_Z1',
#  'BPReq_YC_US_PRECH_BASE',
#  'Brk_TEMP_CALIPER',
#  'Brk_TEMP_PAD',
#  'BrkNrmlLngFrc',
#  'BTWNCounter_FL',
#  'BTWNCounter_FR',
#  'CAL_ACTV_TMR',
#  'CalWhlVelCor_FL',
#  'CalWhlVelCor_FR',
#  'CalWhlVelCor_RL',
#  'CalWhlVelCor_RR',
#  'CAN_COMP_AX',
#  'CAN_COMP_AY',
#  'CAN_COMP_AZ',
#  'CAN_COMP_RR',
#  'CAN_COMP_YR',
#  'CAN_LONG_ACC_GND',
#  'CAN_RSC_STANDSTILL',
#  'CAN_SEF_IMU_STATE_00',
#  'CAN_SEF_IMU_STATE_01',
#  'CAN_SEF_IMU_STATE_02',
#  'CAN_SEF_IMU_STATE_03',
#  'CAN_SEF_IMU_STATE_04',
#  'CAN_TRVL_DIRECTION',
#  'CAN_VEH_SPEED_GND',
#  'CAN_VEH_SPEED_GND_Z1',
#  'CAN_VHCL_STBLTY_STAT',
#  'CAN_YAW_STAB_INDEX',
#  'CAN_YAW_TGT_LINEAR',
#  'CAN_YAW_TGT_LINEAR_Z1',
#  'CAN_YAW_TGT_NON_LINEAR',
#  'CC_ACTIVE_TIMER',
#  'CC_BANK',
#  'CC_CONS_THRESH',
#  'CC_DISABLED_BY_TIMER',
#  'CC_FULL_DISABLE_SSDB',
#  'CC_IN_SLIP_TORQUE_LIMIT',
#  'CC_MU_SENS_DB',
#  'CC_NOT_ACTIVE_TIMER',
#  'CC_NRML_LONG_FORCE_LIMIT',
#  'CC_SLIP_DIS_CNT',
#  'CC_SLIPMAG_GRTR_LST_LOOP',
#  'CC_SOFT_DISABLE_SSDB',
#  'CC_SPD_SENS_DB',
#  'CC_THRTL_SENS_DB',
#  'CC_YawVelTgt',
#  'CCDrvtvTrq',
#  'CCIntTrq',
#  'CCNrmlLngFrc',
#  'CCPropTrq',
#  'CHANGING_SWA_COUNTER_00',
#  'CHANGING_SWA_COUNTER_01',
#  'Cnt_SS_Lin00',
#  'Cnt_SS_Lin01',
#  'cnt_VY_LARGER_THAN_VYLIN',
#  'COMMANDED_GEAR',
#  'COMPENSATED_ROLLRATE',
#  'Continue_Grounded_Build_FL',
#  'Continue_Grounded_Build_FR',
#  'Continue_Grounded_Build_RL',
#  'Continue_Grounded_Build_RR',
#  'Continue_Grounded_Passive_FL',
#  'Continue_Grounded_Passive_FR',
#  'Continue_Grounded_Passive_RL',
#  'Continue_Grounded_Passive_RR',
#  'Continue_Grounded_Release_FL',
#  'Continue_Grounded_Release_FR',
#  'Continue_Grounded_Release_RL',
#  'Continue_Grounded_Release_RR',
#  'Continue_Lifted_Build_FL',
#  'Continue_Lifted_Build_FR',
#  'Continue_Lifted_Build_RL',
#  'Continue_Lifted_Build_RR',
#  'Continue_Lifted_Release_FL',
#  'Continue_Lifted_Release_FR',
#  'Continue_Lifted_Release_RL',
#  'Continue_Lifted_Release_RR',
#  'Control_Mom_FdFwd_US_LHT',
#  'Control_Mom_FdFwd_US_RHT',
#  'Control_Mom_OS_LHT_PrCncl',
#  'Control_Mom_OS_RHT_PrCncl',
#  'Control_Mom_US_LHT_PrCncl',
#  'Control_Moment_OS_Integral_LHT',
#  'Control_Moment_OS_Integral_RHT',
#  'Control_Moment_OS_LHT',
#  'Control_Moment_OS_PD_LHT',
#  'Control_Moment_OS_PD_RHT',
#  'Control_Moment_OS_PID_LHT',
#  'Control_Moment_OS_PID_RHT',
#  'Control_Moment_OS_RHT',
#  'Control_Moment_US_FDBK_LHT',
#  'Control_Moment_US_FDBK_RHT',
#  'Control_Moment_US_FL',
#  'Control_Moment_US_FR',
#  'Control_Moment_US_LHT',
#  'Control_Moment_US_RHT',
#  'CosSteer',
#  'CUM_FL_PERCENT',
#  'CUM_FR_PERCENT',
#  'CUM_RL_PERCENT',
#  'CurvCntrlFdbk',
#  'dAyForTransControl',
#  'DAyFromBetaPRA',
#  'dAYFromSWA',
#  'DAyFromYawAcc',
#  'DecelBound',
#  'DELTA_SWA_INT_00',
#  'DELTA_SWA_INT_01',
#  'delta_time',
#  'DIST_TRAVELED',
#  'DNCF',
#  'DOOR_MESSAGE_PRESENT',
#  'DRIVE_MODE',
#  'DRIVE_MODE_OS_ETR_ENABLE',
#  'DRIVE_TORQUE_FL',
#  'DRIVE_TORQUE_FR',
#  'DRIVE_TORQUE_RL',
#  'DRIVE_TORQUE_RR',
#  'DriverDemand',
#  'DrvDisLampTmr',
#  'DrvrRqNrmlLngFrc',
#  'ECU_INITIALIZATION',
#  'ElecMotBrkEb100_Data.St.Ena_C0',
#  'ElecMotBrkEb100_Data.St.EvtCnt_C0',
#  'ElecMotBrkEb100_Data.St.EvtCntStored_C0',
#  'ElecMotBrkEb100_Data.St.MotBrkActv_C0',
#  'ElecMotBrkEb100_Data.St.St_C0',
#  'ElecMotBrkEb100_Data.StrkInitComplete_C0',
#  'ELOCKER_ENGAGED_TIMER',
#  'ELOCKER_ENGAGED_W_DELAY',
#  'ENABLD_FSC_CNTRLR_MASK',
#  'EPROM_b_STORAGE',
#  'EPROM_b_VALUES_VALID01',
#  'EPROM_b_VHCL_STANDSTILL',
#  'EPROM_FLAGS',
#  'EPROM_LAT_ACC',
#  'EPROM_LAT_ACC_MAX_OFFST',
#  'EPROM_LAT_ACC_MIN_OFFST',
#  'EPROM_LONG_ACC',
#  'EPROM_LONG_ACC_MAX_OFFST',
#  'EPROM_LONG_ACC_MIN_OFFST',
#  'EPROM_PITCH_OFFST',
#  'EPROM_ROLL_RATE_MAX_OFFST',
#  'EPROM_ROLL_RATE_MIN_OFFST',
#  'EPROM_WRITE_REQ',
#  'EPROM_YAW_MISALIGNMENT',
#  'EPROM_YAW_RATE_MAX_OFFST',
#  'EPROM_YAW_RATE_MIN_OFFST',
#  'EST_AVG_ROLL_GRAD',
#  'Estimated_Mu',
#  'ETR_RDX_US_DB',
#  'FC_AX_ENTRY',
#  'FC_AY_ENTRY',
#  'FC_BANK_ANGLE_UNCERT',
#  'FC_BANK_ENTRY',
#  'FC_BrkCtrFnd_B_Stat',
#  'FC_BUS_MON_ALLOWED',
#  'FC_CALC_CHKSUM',
#  'FC_CAN_HOLD_CNT',
#  'FC_CAN_HOLD_OFFST',
#  'FC_CAN_OFFST_RLMTD',
#  'FC_CAN_REL_SWA_CTR',
#  'FC_CAN_SWA_DELTA',
#  'FC_CAN_SWA_DELTA_RAW',
#  'FC_CAN_SWA_MESSAGE',
#  'FC_CAN_SWA_OFFST',
#  'FC_CHKSM_WRITE',
#  'FC_CNTR_NOT_FOUND',
#  'FC_CNTR_NOT_FOUND_INPT_FAILURE',
#  'FC_CNTR_NOT_FOUND_Qf_FAILURE',
#  'FC_CompQfFaultyTimer',
#  'FC_ERROR_CNT',
#  'FC_FAULT',
#  'FC_FILTER_CNTR',
#  'FC_FineOffstLearningEnabled',
#  'FC_FLAGS',
#  'FC_HOLD_CNT',
#  'FC_HOLD_OFFSET',
#  'FC_IGN_CYCLE',
#  'FC_IGN_ON_TIMER',
#  'FC_INIT_COMPLETE',
#  'FC_INPT_SNSR_FAIL',
#  'FC_INT_OFFSET_RESIDUAL',
#  'FC_INT_SWA_DELTA_VEL',
#  'FC_INTERFACE_FAULT',
#  'FC_LAMP_REQUEST',
#  'FC_LatAccBank',
#  'FC_MAX_RESETS_REACHED',
#  'FC_MIN_VX_TO_MON_REL_INIT_QF_MET',
#  'FC_MODE',
#  'FC_MODE_COUNTER',
#  'FC_MovAvgLatAcc',
#  'FC_MovAvgRefVel',
#  'FC_MovAvgYawRate',
#  'FC_NUM_PTS_FOR_AVG',
#  'FC_NVRAM_NUMPTS',
#  'FC_NVRAM_OFFST',
#  'FC_NVRAM_VALID',
#  'FC_NVSC_2_CNT',
#  'FC_OFFSET_CONVERGE_COUNTER',
#  'FC_Qf1_Failure',
#  'FC_Qf1Timer',
#  'FC_Qf2_Failure',
#  'FC_Qf2Timer',
#  'FC_Qf_Fault_Recovery_Counter',
#  'FC_RESET',
#  'FC_RESET_COUNT',
#  'FC_RLMTD_SWA_OFFST',
#  'FC_STEERING_RATIO',
#  'FC_StePinCompAnEst_D_Qf',
#  'FC_StePinOffst_An_Est',
#  'FC_StePinOffst_D_Stat',
#  'FC_StePinOffst_No_Cnt',
#  'FC_StePinOffst_No_Cs',
#  'FC_STORED_CHKSUM',
#  'FC_STORED_NUMPTS',
#  'FC_STORED_OFFSET',
#  'FC_SWA_DELTA',
#  'FC_SWA_DELTA_RAW',
#  'FC_SWA_DELTA_VEL',
#  'FC_SWA_OFFSET',
#  'FC_SWA_SNSR_FAIL',
#  'FC_SWABANK_ENTRY',
#  'FC_SwaSensor_Fault_Recovery_Counter',
#  'FC_SWAVEL_ENTRY',
#  'FC_TEMP_SWA_OFFST',
#  'FC_VX_ENTRY',
#  'FC_WZ_ENTRY',
#  'FC_WZDOT_ENTRY',
#  'FEBC_Vers_Info',
#  'FEBC_Vers_Info_Index',
#  'FEBCIn_b_Abs_B_Falt',
#  'FEBCIn_b_ECU_INITIALIZATION_FEBC',
#  'FEBCIn_b_OnePdlDrvDeny_B_Stat',
#  'FEBCIn_b_PrplDrgCtlActv_B_Actl',
#  'FEBCIn_b_PrplTqMnRgen_B_Actl',
#  'FEBCIn_b_RgenBrkDynoMde_B_Actl',
#  'FEBCIn_b_RgnEPROM_Flt_Actl',
#  'FEBCIn_b_Veh_HEV',
#  'FEBCIn_b_VHCL_IN_ETCS_CNTRL_FEBC',
#  'FEBCIn_b_WHL_IN_ABS_CNTRL_FEBC_00',
#  'FEBCIn_b_WHL_IN_ABS_CNTRL_FEBC_01',
#  'FEBCIn_b_WHL_IN_ABS_CNTRL_FEBC_02',
#  'FEBCIn_b_WHL_IN_ABS_CNTRL_FEBC_03',
#  'FEBCIn_b_WHL_IN_AYC_CNTRL_FEBC_00',
#  'FEBCIn_b_WHL_IN_AYC_CNTRL_FEBC_01',
#  'FEBCIn_b_WHL_IN_AYC_CNTRL_FEBC_02',
#  'FEBCIn_b_WHL_IN_AYC_CNTRL_FEBC_03',
#  'FEBCIn_b_WHL_IN_BTCS_CNTRL_FEBC_00',
#  'FEBCIn_b_WHL_IN_BTCS_CNTRL_FEBC_01',
#  'FEBCIn_b_WHL_IN_BTCS_CNTRL_FEBC_02',
#  'FEBCIn_b_WHL_IN_BTCS_CNTRL_FEBC_03',
#  'FEBCIn_b_WHL_IN_RSC_CNTRL_FEBC_00',
#  'FEBCIn_b_WHL_IN_RSC_CNTRL_FEBC_01',
#  'FEBCIn_b_WHL_IN_RSC_CNTRL_FEBC_02',
#  'FEBCIn_b_WHL_IN_RSC_CNTRL_FEBC_03',
#  'FEBCIn_b_WSS_FAULT_FEBC_00',
#  'FEBCIn_b_WSS_FAULT_FEBC_01',
#  'FEBCIn_b_WSS_FAULT_FEBC_02',
#  'FEBCIn_b_WSS_FAULT_FEBC_03',
#  'FEBCIn_ss_AirAmb_Te_Actl',
#  'FEBCIn_ss_AutonmsArbBrkTqRq',
#  'FEBCIn_ss_BrkPdlTrvl',
#  'FEBCIn_ss_EPROM_FEBC_AvgWhlTemp',
#  'FEBCIn_ss_PrplWhlRgenMn_Tq_Actl',
#  'FEBCIn_ss_PrplWhlTot2_Tq_Actl',
#  'FEBCIn_ss_PrplWhlTot_Tq_Rq',
#  'FEBCIn_ss_PrplWhlTot_Tq_RqDrgTqCtrl',
#  'FEBCIn_ss_RAW_WHL_ANGVEL_FEBC_00',
#  'FEBCIn_ss_RAW_WHL_ANGVEL_FEBC_01',
#  'FEBCIn_ss_RAW_WHL_ANGVEL_FEBC_02',
#  'FEBCIn_ss_RAW_WHL_ANGVEL_FEBC_03',
#  'FEBCIn_ss_TIRE_CIRC_BUS_FEBC',
#  'FEBCIn_ss_WHL_BRK_PRESS_EST_FEBC_00',
#  'FEBCIn_ss_WHL_BRK_PRESS_EST_FEBC_01',
#  'FEBCIn_ss_WHL_BRK_PRESS_EST_FEBC_02',
#  'FEBCIn_ss_WHL_BRK_PRESS_EST_FEBC_03',
#  'FEBCIn_uc_ABSSlipIndex_00',
#  'FEBCIn_uc_ABSSlipIndex_01',
#  'FEBCIn_uc_ABSSlipIndex_02',
#  'FEBCIn_uc_ABSSlipIndex_03',
#  'FEBCIn_uc_AirAmb_Te_Actl_err',
#  'FEBCIn_uc_AirAmbTe_D_QF',
#  'FEBCIn_uc_AirAmbTe_D_QF_err',
#  'FEBCIn_uc_ApedPos_Pc_ActlArb_err',
#  'FEBCIn_uc_AutonmsArbBrkTqRq_QF',
#  'FEBCIn_uc_AutonmsBrk_EvntType',
#  'FEBCIn_uc_BpedMove_D_Actl',
#  'FEBCIn_uc_BrkPdlTrvl_QF',
#  'FEBCIn_uc_CluPdlPos_Pc_Meas_err',
#  'FEBCIn_uc_CluPdlPosPcMeas_D_Qf',
#  'FEBCIn_uc_CluPdlPosPcMeas_D_Qf_err',
#  'FEBCIn_uc_EPROM_FrtAdapFricFactor',
#  'FEBCIn_uc_EPROM_RrAdapFricFactor',
#  'FEBCIn_uc_GearLvrPos_D_Actl',
#  'FEBCIn_uc_GearLvrPos_D_Actl_err',
#  'FEBCIn_uc_GearNtrl_D_Stat',
#  'FEBCIn_uc_GearNtrl_D_Stat_err',
#  'FEBCIn_uc_GearRvrse_D_Actl',
#  'FEBCIn_uc_GearRvrse_D_Actl_err',
#  'FEBCIn_uc_Global_Real_Time_err',
#  'FEBCIn_uc_OnePdlDrv_D_Stat',
#  'FEBCIn_uc_OnePdlDrv_D_Stat_err',
#  'FEBCIn_uc_OnePdlDrvBrk_D_Rq',
#  'FEBCIn_uc_OnePdlDrvBrk_D_Rq_err',
#  'FEBCIn_uc_PrplDrgCtlActv_B_QF',
#  'FEBCIn_uc_PrplTqMnRgen_B_Actl_err',
#  'FEBCIn_uc_PrplWhlRgenMn_Tq_Actl_err',
#  'FEBCIn_uc_PrplWhlRgenMn_Tq_Actl_QF',
#  'FEBCIn_uc_PrplWhlTot2_Tq_Actl_err',
#  'FEBCIn_uc_PrplWhlTot2_Tq_Actl_QF',
#  'FEBCIn_uc_PrplWhlTot_Tq_Rq_err',
#  'FEBCIn_uc_PwPckTq_D_Stat',
#  'FEBCIn_uc_PwPckTq_D_Stat_err',
#  'FEBCIn_uc_SDM_ST_DRV_MDE_ACTL',
#  'FEBCIn_uc_TIRE_CIRC_BUS_err',
#  'FEBCIn_uc_Transmission_Type',
#  'FEBCIn_uc_Transmission_Type_err',
#  'FEBCIn_uc_VehStop_D_Stat',
#  'FEBCIn_uc_WHL_BRK_PRESS_EST_QF_00',
#  'FEBCIn_uc_WHL_BRK_PRESS_EST_QF_01',
#  'FEBCIn_uc_WHL_BRK_PRESS_EST_QF_02',
#  'FEBCIn_uc_WHL_BRK_PRESS_EST_QF_03',
#  'FEBCIn_uc_WHL_BRK_PRESS_SENS_AVAIL_00',
#  'FEBCIn_uc_WHL_BRK_PRESS_SENS_AVAIL_01',
#  'FEBCIn_uc_WHL_BRK_PRESS_SENS_AVAIL_02',
#  'FEBCIn_uc_WHL_BRK_PRESS_SENS_AVAIL_03',
#  'FEBCIn_uc_WhlDirAvgDrv_D_Actl',
#  'FEBCIn_uc_WhlDirAvgDrv_D_Actl_err',
#  'FEBCIn_uc_YSC_Disabled',
#  'FEBCIn_ul_CLOCK_FEBC_IN',
#  'FEBCIn_ul_EPROM_LastShutDown_Time',
#  'FEBCIn_ul_Global_Real_Time',
#  'FEBCIn_us_ApedPos_Pc_ActlArb',
#  'FEBCIn_us_CluPdlPos_Pc_Meas',
#  'FEBCIn_us_EPROM_AcmlFricEngy',
#  'FEBCIn_us_SuppBrkFrt_Press_RqArb',
#  'FEBCIn_us_SuppBrkRr_Press_RqArb',
#  'FEBCIn_us_SuppBrkTot_Tq_RqDrv',
#  'FEBCIn_us_VehLatComp_A_Actl',
#  'FEBCIn_us_VehLongComp_A_Actl',
#  'FEBCIn_us_VehOverGnd_V_Est',
#  'FEBCIn_us_VehYawComp_W_Actl',
#  'FEBCIn_us_VehYawLin_W_Rq',
#  'FEBCIn_us_WHL_BRK_PRESS_SENS_00',
#  'FEBCIn_us_WHL_BRK_PRESS_SENS_01',
#  'FEBCIn_us_WHL_BRK_PRESS_SENS_02',
#  'FEBCIn_us_WHL_BRK_PRESS_SENS_03',
#  'FEBCOut_b_PRNDLDir_fail',
#  'FEBCOut_b_PrplWhlRgenMnTqActl_fail',
#  'FEBCOut_b_PrplWhlTot2TqActl_fail',
#  'FEBCOut_b_PrplWhlTotTqRq_fail',
#  'FEBCOut_b_PTTqMntr_fail',
#  'FEBCOut_b_RgenTqFalt_B_Actl',
#  'FEBCOut_b_RgnPrplDrgCtlActv_B_Actl',
#  'FEBCOut_b_RollDir_fail',
#  'FEBCOut_b_RTRPrefill_Actv',
#  'FEBCOut_ss_AutonmsCreepCanclBrkTqRq',
#  'FEBCOut_ss_AutonmsOnePdlBrkTqRq',
#  'FEBCOut_ss_FEBC_AvgWhlTemp',
#  'FEBCOut_ss_RgnPrplWhlTot_Tq_RqMn',
#  'FEBCOut_uc_FrtAdapFricFactor',
#  'FEBCOut_uc_RrAdapFricFactor',
#  'FEBCOut_ul_CLOCK_FEBC_OUT',
#  'FEBCOut_us_AcmlFricEngy',
#  'FEBCOut_us_BrkTot_Tq_Actl',
#  'FEBCOut_us_BrkTot_Tq_RqArb',
#  'FEBCOut_us_BrkTot_Tq_RqDrv',
#  'FEBCOut_us_RgnFrontPressRq',
#  'FEBCOut_us_RgnRearPressRq',
#  'FINAL_WHEEL_LIFT_STATUS_FL',
#  'FINAL_WHEEL_LIFT_STATUS_FR',
#  'FINAL_WHEEL_LIFT_STATUS_RL',
#  'FINAL_WHEEL_LIFT_STATUS_RR',
#  'FinalMaxRtLmtdDAyDt',
#  'FinalMinDAyDt',
#  'FLT_ABS_GLBL_ROLL_PLAUS',
#  'FLT_ABS_RR_FROM_PITCH',
#  'FLT_DNCF',
#  'FLT_ETR_ERR',
#  'FLT_FRNT_LNR_SS',
#  'FLT_INSTANT_BNK_ANG_UNCERTAINTY',
#  'FLT_LAT_ACC_OS_ETR',
#  'FLT_LAT_ACC_RESTING',
#  'FLT_LONG_ACC_RESTING',
#  'FLT_RESIDUE',
#  'FLT_ROAD_PITCH_00',
#  'FLT_ROAD_PITCH_01',
#  'FLT_ROAD_PITCH_02',
#  'FLT_ROAD_PITCH_03',
#  'FLT_ROAD_PITCH_NRO',
#  'FLT_ROAD_PITCH_NRO_RL',
#  'FLT_ROLL_RATE_INT',
#  'FLT_SINE_PITCH_ANGLE',
#  'FLT_SSRADOT_4CC',
#  'FLT_SWA_4_SWA_VEL',
#  'FLT_WHL_VEL_EST_FL',
#  'FLT_WHL_VEL_EST_FR',
#  'FLT_WHL_VEL_EST_RL',
#  'FLT_WHL_VEL_EST_RR',
#  'FLT_YAW_RATE_INT',
#  'FLT_YAW_RATE_Z1',
#  'FLT_YR_COMP_REST',
#  'FltDerivOfFrntLinSS4PD',
#  'FnlCCEtrRqst',
#  'Frction_Hi_Slip',
#  'FREQUENCY_WEIGHTED_SRA',
#  'FSC_Awd_DIS_TqMx',
#  'FSC_AwdTq_RqMx',
#  'FSC_CONTROL_TUNING_MODE',
#  'FSC_DIS_BY_DIAG_MODE',
#  'FSC_EPROM_WRITE_CNTR',
#  'FSC_EPROM_WRITE_TMR',
#  'FSC_MODE_OUT',
#  'FSCArbtWnr_FL',
#  'FSCArbtWnr_FR',
#  'FSCArbtWnr_RL',
#  'FSCArbtWnr_RR',
#  'FscCalChkState',
#  'FSCRqstSuplrInhbtUS',
#  'FwdCond1_Rr_Whl',
#  'GearRatioSqrd',
#  'GLBL_ROLL_PLAUS',
#  'GLOBAL_AZ_FLT',
#  'GLOBAL_AZ_MAX',
#  'GLOBAL_AZ_MIN',
#  'GLOBAL_AZ_NOM',
#  'GLOBAL_NOM_ROLL_WASHOUT',
#  'GLOBAL_NOM_ROLL_WASHOUT_NEG',
#  'GLOBAL_NOM_ROLL_WASHOUT_POS',
#  'GLOBAL_PITCH_ANG_MAX',
#  'GLOBAL_PITCH_ANG_MIN',
#  'GLOBAL_PITCH_ANG_NOM',
#  'GPA_4_RVT',
#  'GPA_4_Vref',
#  'HIGH_LAT_ACCEL_COUNTER',
#  'HYBRID_CONFIGURED',
#  'I_wheel_total',
#  'IBA_LAT_VEL_MAX',
#  'IBA_LAT_VEL_MIN',
#  'IBA_LAT_VEL_NOM',
#  'IGN_RUN_ACHIEVED',
#  'IGN_SWITCH_STATUS',
#  'IGNITION_STAT',
#  'INC_SSRA_TIMERFL',
#  'INC_SSRA_TIMERFR',
#  'IndWhVelD4_FL',
#  'IndWhVelD4_FR',
#  'IndWhVelD4_RL',
#  'IndWhVelD4_RR',
#  'INST_BANK_ANGLE_EST_INT',
#  'InsTBankAng',
#  'INTEG_PITCH_ANG_MAX',
#  'INTEG_PITCH_ANG_MIN',
#  'INTEG_PITCH_ANG_NOM',
#  'INTEGRATED_VX_1',
#  'INTEGRATED_VX_3',
#  'INTEGRATED_VX_FOR_VREF',
#  'INTEGRATED_VX_NOM',
#  'IVD_CONTROL_STATUS_FL',
#  'IVD_CONTROL_STATUS_FR',
#  'IVD_CONTROL_STATUS_RL',
#  'IVD_CONTROL_STATUS_RR',
#  'K_LONG_NORM_LOAD',
#  'KFdFwd',
#  'KineticEnergy',
#  'KUS_FILT',
#  'LARGE_LAT_ACC_COUNTER',
#  'Large_Opp_Axle_Decel_Timer_FL',
#  'Large_Opp_Axle_Decel_Timer_FR',
#  'Large_Opp_Axle_Decel_Timer_RL',
#  'Large_Opp_Axle_Decel_Timer_RR',
#  'LAT_ACC_DYN',
#  'LAT_ACC_DYN_Z1',
#  'LAT_ACC_DYN_Z2',
#  'LAT_ACC_OFFSET',
#  'LAT_ACC_OFFSET_RESTING',
#  'LAT_ACC_OFFSET_UNCERTAINTY',
#  'LAT_ACC_OFFSET_UNCERTAINTY2',
#  'LAT_ACC_SNSOR_INVLID',
#  'LAT_VEL_LAG_MAX',
#  'LAT_VEL_LAG_MIN',
#  'LAT_VEL_LAG_NOM',
#  'LIFT_BUILD_TIMER_FL',
#  'LIFT_BUILD_TIMER_FR',
#  'LIFT_BUILD_TIMER_RL',
#  'LIFT_BUILD_TIMER_RR',
#  'Lift_Press_Driven_Hold_FL',
#  'Lift_Press_Driven_Hold_FR',
#  'Lift_Press_Driven_Hold_RL',
#  'Lift_Press_Driven_Hold_RR',
#  'LIFT_RELEASE_TIMER_FL',
#  'LIFT_RELEASE_TIMER_FR',
#  'LIFT_RELEASE_TIMER_RL',
#  'LIFT_RELEASE_TIMER_RR',
#  'LIFT_STATE_FL',
#  'LIFT_STATE_FR',
#  'LIFT_STATE_RL',
#  'LIFT_STATE_RR',
#  'LIFT_TIMER_FL',
#  'LIFT_TIMER_FR',
#  'LIFT_TIMER_RL',
#  'LIFT_TIMER_RR',
#  'LiftWheel_FL',
#  'LiftWheel_FR',
#  'LiftWheel_RL',
#  'LiftWheel_RR',
#  'Limit_Yaw_Rate_Uncert',
#  'LIN_LAT_VEL_FRONT',
#  'LIN_LAT_VEL_REAR',
#  'LONG_ACC_GND',
#  'LONG_ACC_GND_REMAINDER',
#  'LONG_ACC_OFFSET',
#  'LONG_ACC_OFFSET_RESTING',
#  'LONG_ACC_OFFSET_UNCERTAINTY',
#  'LONG_ACC_OFFSET_UNCERTAINTY2',
#  'LONG_ACC_RPA_OFFSET_UNCERTAINTY',
#  'LONG_ACC_SNSOR_INVLID',
#  'LONG_TERM_COMP_UPDATE_CLOCK',
#  'LONG_VEL_AT_CORNER_FL',
#  'LONG_VEL_AT_CORNER_FR',
#  'LONG_VEL_AT_CORNER_RL',
#  'LONG_VEL_AT_CORNER_RR',
#  'LongAccYc',
#  'LowMuAG_Release_FL',
#  'LowMuAG_Release_FR',
#  'LowMuAG_Release_RL',
#  'LowMuAG_Release_RR',
#  'LowTqHighSlip',
#  'Lrg_Decel_Tmr_Opp_Whl_On_Same_Axle_FL',
#  'Lrg_Decel_Tmr_Opp_Whl_On_Same_Axle_FR',
#  'Lrg_Decel_Tmr_Opp_Whl_On_Same_Axle_RL',
#  'Lrg_Decel_Tmr_Opp_Whl_On_Same_Axle_RR',
#  'MAG_ROLLACC',
#  'MAG_SWAR',
#  'MatchingPressure',
#  'MAX_AXLE_TORQUE',
#  'MAX_AXLE_TORQUE_BASE',
#  'MAX_AXLE_TORQUE_FLT',
#  'MAX_AXLE_TORQUE_FLT_1',
#  'MAX_AXLE_TORQUE_FLT_INT',
#  'MAX_AXLE_TORQUE_TRL',
#  'MAX_COMBINED_FORCE',
#  'MAX_LONG_FORCE',
#  'MAX_SSRA_DOT_4_PRED_PD_ON_INSIDE_WHL',
#  'MdMngrBMODETRDBAdr',
#  'MdMngrBMODETRFFMlt',
#  'MdMngrBMODETRKPMlt',
#  'MdMngrCCAyEntAdr',
#  'MdMngrCCBsDBMlt',
#  'MdMngrCCMuDBMlt',
#  'MdMngrCCPrpTqMlt',
#  'MdMngrCCSpdDBAdr',
#  'MdMngrCCThrDBMlt',
#  'MdMngrCCTqLmtAdr',
#  'MdMngrSSRABPAdr',
#  'MdMngrSSRADBAdr',
#  'MdMngrSSRAMlt',
#  'MdMngrTrnsMtchPrMlt',
#  'MdMngrTrnsPDGnMlt',
#  'MdMngrTVbBDBAdr',
#  'MdMngrTVbBMlt',
#  'MdMngrUSPrchMlt',
#  'MdMngrUSPrchThtlAdr',
#  'MdMngrUSPrchTqMlt',
#  'MdMngrUSPrchTqThrsAdr',
#  'MdMngrYCCSPchgPrMlt',
#  'MdMngrYCOSDBAdr',
#  'MdMngrYCOSPrMlt',
#  'MdMngrYCUSDBAdr',
#  'MdMngrYCUSPrMlt',
#  'MdMngrYCYwDmpDBAdr',
#  'MdMngrYCYwDmpPrMlt',
#  'Meas_Mu_F',
#  'Meas_Mu_R',
#  'MinRoughMuForPrchrg',
#  'MinRufMuWzVxForTrnsCtrl',
#  'MismatchedFscCal',
#  'Model_Ay',
#  'Model_Ay_Filt',
#  'Model_Mu',
#  'Model_Mu_F',
#  'Model_Mu_R',
#  'Mu_Baseline',
#  'Mu_Deadband',
#  'Mu_Hold_Timer_YC',
#  'MU_OS_ETR',
#  'Mu_Tau',
#  'NEW_AVG_ROLLG',
#  'NEW_IM_SERIAL_NUMBER',
#  'NEW_PROP_PEAK_HOLD_FL',
#  'NEW_PROP_PEAK_HOLD_FR',
#  'NEW_ROLL_A_COEF',
#  'NEW_ROLL_GRAD',
#  'NewTrgtSlip_FL',
#  'NewTrgtSlip_FR',
#  'NewTrgtSlip_RL',
#  'NewTrgtSlip_RR',
#  'NO_EEPROM_STORAGE_RSC',
#  'NO_YAWRATE_ERROR_CNTR',
#  'noise_WSS_FL',
#  'noise_WSS_FR',
#  'noise_WSS_RL',
#  'noise_WSS_RR',
#  'NORM_LONG_FRC',
#  'NORMAL_LOADS_AzFL',
#  'NORMAL_LOADS_AzFR',
#  'NORMAL_LOADS_AzRL',
#  'NORMAL_LOADS_AzRR',
#  'NORMAL_LOADS_FL',
#  'NORMAL_LOADS_FR',
#  'NORMAL_LOADS_RL',
#  'NORMAL_LOADS_RR',
#  'NrmlX_Cntr',
#  'NUM_LS_STEPS',
#  'OBSERVER_INP1',
#  'OBSERVER_INP2',
#  'OBSERVER_N1',
#  'OBSERVER_N2',
#  'OFFSET_TRACKING_FLAGS1',
#  'OFFSET_TRACKING_FLAGS2',
#  ...]

# %%
# Out:
# --- 0.2872316837310791 seconds ---
